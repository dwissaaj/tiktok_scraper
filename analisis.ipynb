# %%
import pandas as pd

# %%
df = pd.read_excel("posindonesia.xlsx")

df
# Out:
#      Unnamed: 0                   id  \
# 0             0  6979146243037547777
# 1             1  6978400610156662018
# 2             2  6977658192067087618
# 3             3  6977297242071780610
# 4             4  6976551348045319425
# ..          ...                  ...
# 205         205  6828328713680112897
# 206         206  6822924605716532481
# 207         207  6818738230918253825
# 208         208  6818078042406079746
# 209         209  6818069894081301762
#
#                                                   desc  createTime  \
# 0    #stitch with @Plangton Eitssss ketangkap hihi ...  1624959115
# 1    #duet with @arianabasseri hadeh hadeh hanassss...  1624785509
# 2    Mr.Postman selalu ingin melayani semuanyanya h...  1624612651
# 3    O-ranger sama customer sama gumushnya gak nih ...  1624528610
# 4    Yang jelas jawabannya bukan gajah hihi.. #fypシ...  1624354943
# ..                                                 ...         ...
# ...

# %%
df['date'] = pd.to_datetime(df['createTime'],unit='s')

# %%
df.to_excel("final pos indonesia.xlsx")
